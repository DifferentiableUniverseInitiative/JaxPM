# %% [markdown]
# # **Multi-Host Particle Mesh Simulation**
#
# In this notebook, we extend our Particle Mesh simulation across **multiple nodes**, enabling simulations at scales not achievable on a single machine. By leveraging distributed GPUs across hosts, we handle larger mesh shapes and box sizes efficiently.
#
# > **Note**: Since there’s no direct way to run a multi-host notebook, I’ll guide you step by step on how to submit an interactive job from a script.

# %% [markdown]
# To run a multi-host simulation, you first need to **allocate a job** with `salloc`. This command requests resources on an HPC cluster.
#
# > **Note**: You can alternatively use `sbatch` with a SLURM script to submit the job. The exact `salloc` parameters may vary depending on your specific HPC cluster configuration.

# %%
# !salloc --account=XXX@a100 -C a100 --gres=gpu:8 --ntasks-per-node=8 --time=00:40:00  --cpus-per-task=8 --hint=nomultithread --qos=qos_gpu-dev --nodes=4 &

# %% [markdown]
# > **Note**: These `salloc` parameters are configured for the **Jean Zay** supercomputer in France. Adaptations might be necessary if using a different HPC cluster.

# %% [markdown]
# **A few hours later**

# %% [markdown]
# Use `!squeue -u $USER -o "%i %D %b"` to **check the JOB ID** and verify your resource allocation.
#
# In this example, we’ve been allocated **32 GPUs split across 4 nodes**.

# %%
# !squeue -u $USER -o "%i %D %b"
# Out:
# JOBID NODES TRES_PER_NODE
# 467745 4 gres/gpu:8

# %% [markdown]
# Unset the following environment variables, as they can cause issues when using JAX in a distributed setting:

# %%
import os

del os.environ["VSCODE_PROXY_URI"]
del os.environ["NO_PROXY"]
del os.environ["no_proxy"]

# %% [markdown]
# ### Checking Available Compute Resources
#
# Run the following command to initialize JAX distributed computing and display the devices available for this job:

# %%
# !srun --jobid=2049655 -n 32 python -c "import jax; jax.distributed.initialize(); print(jax.devices()) if jax.process_index() == 0 else None"
# Out:
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3), CudaDevice(id=4), CudaDevice(id=5), CudaDevice(id=6), CudaDevice(id=7), CudaDevice(id=8), CudaDevice(id=9), CudaDevice(id=10), CudaDevice(id=11), CudaDevice(id=12), CudaDevice(id=13), CudaDevice(id=14), CudaDevice(id=15), CudaDevice(id=16), CudaDevice(id=17), CudaDevice(id=18), CudaDevice(id=19), CudaDevice(id=20), CudaDevice(id=21), CudaDevice(id=22), CudaDevice(id=23), CudaDevice(id=24), CudaDevice(id=25), CudaDevice(id=26), CudaDevice(id=27), CudaDevice(id=28), CudaDevice(id=29), CudaDevice(id=30), CudaDevice(id=31)]
# W0607 17:29:20.137477 4007722 pjrt_client.cc:1613] WatchTasksAsync failed for task 3: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.138679 4007726 pjrt_client.cc:1613] WatchTasksAsync failed for task 4: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.138738 4007721 pjrt_client.cc:1613] WatchTasksAsync failed for task 6: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.138756 4007728 pjrt_client.cc:1613] WatchTasksAsync failed for task 7: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.138804 4007725 pjrt_client.cc:1613] WatchTasksAsync failed for task 5: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.139202 2070915 pjrt_client.cc:1613] WatchTasksAsync failed for task 12: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.139829 4007724 pjrt_client.cc:1613] WatchTasksAsync failed for task 1: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.140124 3080757 pjrt_client.cc:1613] WatchTasksAsync failed for task 23: CANCELLED: CANCELLED
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:1, grpc_message:"CANCELLED"} [type.googleapis.com/tensorflow.DerivedStatus='']
# W0607 17:29:20.140586 2070920 pjrt_client.cc:1613] WatchTasksAsync failed for task 8: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.140611 2070917 pjrt_client.cc:1613] WatchTasksAsync failed for task 11: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.141193 2070919 pjrt_client.cc:1613] WatchTasksAsync failed for task 9: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.141201 2070918 pjrt_client.cc:1613] WatchTasksAsync failed for task 10: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.141415  255744 pjrt_client.cc:1613] WatchTasksAsync failed for task 31: CANCELLED: CANCELLED
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:1, grpc_message:"CANCELLED"} [type.googleapis.com/tensorflow.DerivedStatus='']
# W0607 17:29:20.141477  255746 pjrt_client.cc:1613] WatchTasksAsync failed for task 27: CANCELLED: CANCELLED
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:1, grpc_message:"CANCELLED"} [type.googleapis.com/tensorflow.DerivedStatus='']
# W0607 17:29:20.141620  255747 pjrt_client.cc:1613] WatchTasksAsync failed for task 24: CANCELLED: CANCELLED
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"CANCELLED", grpc_status:1} [type.googleapis.com/tensorflow.DerivedStatus='']
# W0607 17:29:20.141623  255743 pjrt_client.cc:1613] WatchTasksAsync failed for task 29: CANCELLED: CANCELLED
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:1, grpc_message:"CANCELLED"} [type.googleapis.com/tensorflow.DerivedStatus='']
# W0607 17:29:20.142220 2070916 pjrt_client.cc:1613] WatchTasksAsync failed for task 13: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.142666 2070922 pjrt_client.cc:1613] WatchTasksAsync failed for task 14: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.142801 3080762 pjrt_client.cc:1613] WatchTasksAsync failed for task 17: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.142792 3080759 pjrt_client.cc:1613] WatchTasksAsync failed for task 18: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.142792 3080758 pjrt_client.cc:1613] WatchTasksAsync failed for task 19: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.142795 3080764 pjrt_client.cc:1613] WatchTasksAsync failed for task 20: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.142795 3080763 pjrt_client.cc:1613] WatchTasksAsync failed for task 21: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.142792 3080760 pjrt_client.cc:1613] WatchTasksAsync failed for task 22: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.142816 3080761 pjrt_client.cc:1613] WatchTasksAsync failed for task 16: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.143356 2070921 pjrt_client.cc:1613] WatchTasksAsync failed for task 15: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.143376 4007723 pjrt_client.cc:1613] WatchTasksAsync failed for task 0: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.145433  255749 pjrt_client.cc:1613] WatchTasksAsync failed for task 25: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.145437  255748 pjrt_client.cc:1613] WatchTasksAsync failed for task 26: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}
# W0607 17:29:20.145426  255742 pjrt_client.cc:1613] WatchTasksAsync failed for task 28: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.145426  255745 pjrt_client.cc:1613] WatchTasksAsync failed for task 30: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused"}
# W0607 17:29:20.148056 4007727 pjrt_client.cc:1613] WatchTasksAsync failed for task 2: UNAVAILABLE: failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:10.148.8.228:63095: Failed to connect to remote host: Connection refused", grpc_status:14}

# %% [markdown]
# ### Running the Multi-Host Simulation Script
#
# Run the simulation script across 32 processes:
#
# ```bash
# !srun --jobid=2049655 -n 32 python 05-MultiHost_PM.py --mesh_shape 1024 1024 1024 --box_size 1000. 1000. 1000. --halo_size 128 --pdims 16 2
# ```
# The script, located in the same path as this notebook, is named [**05-MultiHost_PM.py**](05-MultiHost_PM.py).

# %% [markdown]
# ### Multi-Host Simulation Script with Arguments
#
# This script is nearly identical to the single-host version, with the main addition being the call to `jax.distributed.initialize()` at the start, enabling multi-host parallelism. It uses a single solver, the **FastPM** scheme (`symplectic_fpm_ode` integrated with diffrax's `SemiImplicitEuler` at a fixed step), matching the single-GPU notebooks. Here's a breakdown of the key arguments:
#
# - **`--pdims`** (`-p`): Specifies processor grid dimensions as two integers, like `16 2` for 16 x 2 device mesh (default is `[1, jax.device_count()]`).
# - **`--mesh_shape`** (`-m`): Defines the simulation mesh shape as three integers (default is `[512, 512, 512]`).
# - **`--box_size`** (`-b`): Sets the physical box size of the simulation as three floating-point values, e.g., `1000. 1000. 1000.` (default is `[500.0, 500.0, 500.0]`).
# - **`--halo_size`** (`-H`): Specifies the halo size for boundary overlap across nodes (default is `64`).
# - **`--snapshots`** (`-st`) : Number of snapshots to save (warning, increases memory usage).
#
# The script also saves results across nodes.

# %%
import subprocess

# Define parameters as variables
jobid = "2049655"
num_processes = 32
script_name = "05-MultiHost_PM.py"
mesh_shape = (1024, 1024, 1024)
box_size = (1000.0, 1000.0, 1000.0)
halo_size = 128
pdims = (16, 2)
snapshots = 2

# Build the command as a list, incorporating variables
command = [
    "srun",
    f"--jobid={jobid}",
    "-n",
    str(num_processes),
    "python",
    script_name,
    "--mesh_shape",
    str(mesh_shape[0]),
    str(mesh_shape[1]),
    str(mesh_shape[2]),
    "--box_size",
    str(box_size[0]),
    str(box_size[1]),
    str(box_size[2]),
    "--halo_size",
    str(halo_size),
    "--pdims",
    str(pdims[0]),
    str(pdims[1]),
    "--snapshots",
    str(snapshots),
]

# Execute the command as a subprocess
subprocess.run(command)
# Out:
# SIZE is 32
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1194: UserWarning: A large amount of constants were captured during lowering (51.54GB total). If this is intentional, disable this warning by setting JAX_CAPTURED_CONSTANTS_WARN_BYTES=-1. To obtain a report of where these constants were encountered, set JAX_CAPTURED_CONSTANTS_REPORT_FRAMES=-1.
#   warnings.warn(message)
# [0] Simulation done
# Solver stats: {'max_steps': Array(4096, dtype=int32, weak_type=True), 'num_accepted_steps': Array(18, dtype=int32, weak_type=True), 'num_rejected_steps': Array(0, dtype=int32, weak_type=True), 'num_steps': Array(18, dtype=int32, weak_type=True)}
# [0] Saving initial_conditions
# [0] initial_conditions saved
# [0] Saving lpt_displacements
# [0] lpt_displacements saved
# [0] Saving ode_solution_0
# [0] ode_solution_0 saved
# [0] Saving ode_solution_1
# [0] ode_solution_1 saved
# W0607 17:32:45.420534 4008352 pjrt_client.cc:1613] WatchTasksAsync failed for task 0: UNAVAILABLE: Cancelling all calls
# Additional GRPC error information from remote target coordination_service while calling /xla.coordination.CoordinationService/WatchTasks:
# :UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"Cancelling all calls"}
# CompletedProcess(args=['srun', '--jobid=2049655', '-n', '32', 'python', '05-MultiHost_PM.py', '--mesh_shape', '1024', '1024', '1024', '--box_size', '1000.0', '1000.0', '1000.0', '--halo_size', '128', '--pdims', '16', '2', '--snapshots', '2'], returncode=0)

# %% [markdown]
# ### Loading and Visualizing Results
#
# After running the multi-host simulation, we load the saved results from disk:
#
# - **`initial_conditions.npy`**: Initial conditions for the simulation.
# - **`lpt_displacements.npy`**: Linear perturbation displacements.
# - **`ode_solution_0.npy`** and **`ode_solution_1.npy`**: Solutions from the ODE solver at each snapshot.
#
# We then use `plot_fields_single_projection` to visualize these fields and observe the results across multiple snapshots.

# %%
import numpy as np

initial_conditions = np.load("fields/initial_conditions.npy")
lpt_displacements = np.load("fields/lpt_displacements.npy")
ode_solution_0 = np.load("fields/ode_solution_0.npy")
ode_solution_1 = np.load("fields/ode_solution_1.npy")

# %%
from jaxpm.plotting import plot_fields_single_projection

fields = {
    "Initial Conditions": initial_conditions,
    "LPT Field": lpt_displacements,
    "ODE Solution 0": np.log10(ode_solution_0 + 0.1),
    "ODE Solution 1": np.log10(ode_solution_1 + 0.1),
}
plot_fields_single_projection(fields)
